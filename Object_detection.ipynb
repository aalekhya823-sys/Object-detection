# %%
# %pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 53.3 MB/s eta 0:00:00
# ...

# %%
import ultralytics
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
ultralytics.checks()
# Out:
# Ultralytics 8.4.27 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 21.3/107.7 GB disk)

# %%
# !yolo predict model=yolo11n.pt source='https://images.picxy.com/cache/2019/7/19/08f772304c2baaa8e7c2f6c028d2a740.jpg'
# Out:
# Ultralytics 8.4.27 🚀 Python-3.12.13 torch-2.10.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# Found https://images.picxy.com/cache/2019/7/19/08f772304c2baaa8e7c2f6c028d2a740.jpg locally at 08f772304c2baaa8e7c2f6c028d2a740.jpg
# image 1/1 /content/08f772304c2baaa8e7c2f6c028d2a740.jpg: 448x640 1 person, 1 laptop, 1 cell phone, 172.9ms
# Speed: 4.1ms preprocess, 172.9ms inference, 2.0ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to /content/runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
